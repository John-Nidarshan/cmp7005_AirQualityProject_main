# %% [markdown]
# <a href="https://colab.research.google.com/github/John-Nidarshan/cmp7005_AirQualityProject_main/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git config --global user.name "John-Nidarshan"
# !git config --global user.email "jhonnidarshan@gmail.com"
# !git clone https://github.com/John-Nidarshan/cmp7005_AirQualityProject_main.git
# Out:
# Cloning into 'cmp7005_AirQualityProject_main'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 29 (delta 0), reused 29 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (29/29), 769.16 KiB | 18.76 MiB/s, done.

# %%
# !cd cmp7005_AirQualityProject_main
# !ls
# Out:
# cmp7005_AirQualityProject_main	sample_data
